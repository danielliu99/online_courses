# %% [markdown]
# # 1. Creating, Reading and Writing

# %%
import pandas as pd

# %% [markdown]
# ## Creating

# %% [markdown]
# ### DataFrame

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']}, 
            index = ['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series

# %% [markdown]
# *Series have no column name.*

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 40, 50], 
         index = ['2015 Sales', '2016 Sales', '2017 Sales'], 
         name = 'Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    40
# 2017 Sales    50
# Name: Product A, dtype: int64

# %% [markdown]
# # 2. Indexing, Selecting and Assigning

# %%
pd.set_option('max_rows', 5)
reviews = pd.read_csv('./winemag-data_first150k.csv', 
                     index_col=0)

# %%
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# ...                         ...
# 150928                   Gosset
# 150929            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# ## Native accessing

# %%
reviews.country
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews['country']
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews['country'][0]
# Out:
# 'US'

# %% [markdown]
# ## Indexing in pandas

# %% [markdown]
# ### Index-based selection

# %%
# one row
reviews.iloc[0]
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
#                                      ...
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, Length: 10, dtype: object

# %%
# one column
reviews.iloc[:, 0]
# Out:
# 0             US
# 1          Spain
#            ...
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
# 0:3 EXCLUSIVELY last one
reviews.iloc[0:3, ]
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
#
#          region_1 region_2             variety                   winery
# 0     Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1            Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2  Knights Valley   Sonoma     Sauvignon Blanc                 Macauley

# %% [markdown]
# ### Label-based selection

# %%
reviews.loc[0, 'country']
# Out:
# 'US'

# %%
# 0:3 INCLUSIVELY last one
reviews.loc[0:3, ['country', 'price']]
# Out:
#   country  price
# 0      US  235.0
# 1   Spain  110.0
# 2      US   90.0
# 3      US   65.0

# %%
reviews.loc[[1,2,3,5,8]]
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# 2      Knights Valley             Sonoma  Sauvignon Blanc
# 3   Willamette Valley  Willamette Valley       Pinot Noir
# 5                Toro                NaN    Tinta de Toro
# 8  Chehalem Mountains  Willamette Valley       Pinot Noir
#
#                     winery    critic  index_backwards
# 1  Bodega Carmen Rodríguez  everyone           150929
# 2                 Macauley  everyone           150928
# 3                    Ponzi  everyone           150927
# 5                Numanthia  everyone           150925
# 8                Bergström  everyone           150922

# %% [markdown]
# ## Manipulating the index

# %%
reviews.set_index('country')
# Out:
#                                                description  \
# country
# US       This tremendous 100% varietal wine hails from ...
# Spain    Ripe aromas of fig, blackberry and cassis are ...
# ...                                                    ...
# France   A perfect salmon shade, with scents of peaches...
# Italy    More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# country
# US                          Martha's Vineyard      96  235.0
# Spain    Carodorum Selección Especial Reserva      96  110.0
# ...                                       ...     ...    ...
# France                        Grand Brut Rosé      90   52.0
# Italy                                     NaN      90   15.0
#
#                    province     region_1 region_2             variety  \
# country
# US               California  Napa Valley     Napa  Cabernet Sauvignon
# Spain        Northern Spain         Toro      NaN       Tinta de Toro
# ...                     ...          ...      ...                 ...
# France            Champagne    Champagne      NaN     Champagne Blend
# Italy    Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                           winery
# country
# US                         Heitz
# Spain    Bodega Carmen Rodríguez
# ...                          ...
# France                    Gosset
# Italy              Alois Lageder
#
# [150930 rows x 9 columns]

# %% [markdown]
# ## Conditional selection

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# ...        ...                                                ...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# ...                    ...     ...    ...                 ...
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                       region_1 region_2       variety            winery
# 10                      Collio      NaN      Friulano  Borgo del Tiglio
# 32      Brunello di Montalcino      NaN    Sangiovese   Abbadia Ardenga
# ...                        ...      ...           ...               ...
# 150927       Fiano di Avellino      NaN   White Blend         Terredora
# 150929              Alto Adige      NaN  Pinot Grigio     Alois Lageder
#
# [23478 rows x 10 columns]

# %%
# BRACKETS!!
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 9)]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# ...        ...                                                ...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# ...                    ...     ...    ...                 ...
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                       region_1 region_2       variety            winery
# 10                      Collio      NaN      Friulano  Borgo del Tiglio
# 32      Brunello di Montalcino      NaN    Sangiovese   Abbadia Ardenga
# ...                        ...      ...           ...               ...
# 150927       Fiano di Avellino      NaN   White Blend         Terredora
# 150929              Alto Adige      NaN  Pinot Grigio     Alois Lageder
#
# [23478 rows x 10 columns]

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 4       France  This is the top wine from La Bégude, named aft...
# 10       Italy  Elegance, complexity and structure come togeth...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province    region_1  \
# 4               La Brûlade      95   66.0            Provence      Bandol
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy      Collio
# ...                    ...     ...    ...                 ...         ...
# 150928     Grand Brut Rosé      90   52.0           Champagne   Champagne
# 150929                 NaN      90   15.0  Northeastern Italy  Alto Adige
#
#        region_2             variety                winery
# 4           NaN  Provence red blend  Domaine de la Bégude
# 10          NaN            Friulano      Borgo del Tiglio
# ...         ...                 ...                   ...
# 150928      NaN     Champagne Blend                Gosset
# 150929      NaN        Pinot Grigio         Alois Lageder
#
# [44576 rows x 10 columns]

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# ...                         ...
# 150928                   Gosset
# 150929            Alois Lageder
#
# [137235 rows x 10 columns]

# %% [markdown]
# ## Assigning data

# %%
# a constant value
reviews['critic'] = 'everyone'
reviews.critic
# Out:
# 0         everyone
# 1         everyone
#             ...
# 150928    everyone
# 150929    everyone
# Name: critic, Length: 150930, dtype: object

# %%
# an iterable of values
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         150930
# 1         150929
#            ...
# 150928         2
# 150929         1
# Name: index_backwards, Length: 150930, dtype: int64

# %% [markdown]
# # 3. Summary Functions and Maps

# %% [markdown]
# ## Summary (statistical) functions

# %%
reviews.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
#              ...
# 75%          90.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.points.mean()
# Out:
# 87.8884184721394

# %%
reviews.country.unique()
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
reviews.country.value_counts()
# Out:
# US           62397
# Italy        23478
#              ...
# Japan            2
# US-France        1
# Name: country, Length: 48, dtype: int64

# %% [markdown]
# ## Maps

# %%
review_points_mean = reviews.points.mean()

# %% [markdown]
# ### map()

# %%
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0         8.111582
# 1         8.111582
#             ...
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %% [markdown]
# ### apply()

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

# %%
reviews.apply(remean_points, axis=1)
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation    points  price  \
# 0                          Martha's Vineyard  8.111582  235.0
# 1       Carodorum Selección Especial Reserva  8.111582  110.0
# ...                                      ...       ...    ...
# 150928                       Grand Brut Rosé  2.111582   52.0
# 150929                                   NaN  2.111582   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                          winery    critic  index_backwards
# 0                         Heitz  everyone           150930
# 1       Bodega Carmen Rodríguez  everyone           150929
# ...                         ...       ...              ...
# 150928                   Gosset  everyone                2
# 150929            Alois Lageder  everyone                1
#
# [150930 rows x 12 columns]

# %% [markdown]
# # 4. Grouping and sorting

# %% [markdown]
# ## Groupwise analysis

# %%
reviews = pd.read_csv('./winemag-data_first150k.csv', index_col=0)

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80      898
# 81     1502
#        ...
# 99       50
# 100      24
# Name: points, Length: 21, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     65.0
# 100    65.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('points').apply(lambda df: df.iloc[0])
# Out:
#         Unnamed: 0    country  \
# points
# 80            7793  Argentina
# 81            2142  Argentina
# ...            ...        ...
# 99            2146      Italy
# 100           2145     France
#
#                                               description  \
# points
# 80      Tropical, soapy aromas are yeasty and flat. Fl...
# 81      This gold-colored stale-smelling Torrontés sme...
# ...                                                   ...
# 99      Perfumed berry, rose, new leather and dark spi...
# 100     Full of ripe fruit, opulent and concentrated, ...
#
#                  designation  points  price          province  \
# points
# 80                       NaN      80   13.0  Mendoza Province
# 81                       NaN      81   12.0  Mendoza Province
# ...                      ...     ...    ...               ...
# 99      Madonna delle Grazie      99  200.0           Tuscany
# 100                      NaN     100  848.0          Bordeaux
#
#                       region_1 region_2                     variety  \
# points
# 80                     Mendoza      NaN                  Chardonnay
# 81                     Mendoza      NaN                   Torrontés
# ...                        ...      ...                         ...
# 99      Brunello di Montalcino      NaN                  Sangiovese
# 100             Pessac-Léognan      NaN  Bordeaux-style White Blend
#
#                      winery
# points
# 80             Tres Exilios
# 81      Cuatro Vacas Gordas
# ...                     ...
# 99             Il Marroneto
# 100      Château Haut-Brion
#
# [21 rows x 11 columns]

# %%
reviews.groupby(['country', 'province']).apply(
    lambda df: df.loc[df.points.idxmax()])
# Out:
#                             Unnamed: 0    country  \
# country   province
# Albania   Mirditë                 4642    Albania
# Argentina Mendoza Province       65331  Argentina
# ...                                ...        ...
# Uruguay   San Jose               70157    Uruguay
#           Uruguay               132482    Uruguay
#
#                                                                   description  \
# country   province
# Albania   Mirditë           This garnet-colored wine made from 100% Kallme...
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
# ...                                                                       ...
# Uruguay   San Jose          While this ranks as one of the best Uruguayan ...
#           Uruguay           They call it Special Barrel, and one sniff tel...
#
#                                                  designation  points  price  \
# country   province
# Albania   Mirditë                                        NaN      88   20.0
# Argentina Mendoza Province                  Nicasia Vineyard      97  120.0
# ...                                                      ...     ...    ...
# Uruguay   San Jose          El Preciado Premier Gran Reserva      89   60.0
#           Uruguay                             Special Barrel      89   50.0
#
#                                     province region_1 region_2    variety  \
# country   province
# Albania   Mirditë                    Mirditë      NaN      NaN    Kallmet
# Argentina Mendoza Province  Mendoza Province  Mendoza      NaN     Malbec
# ...                                      ...      ...      ...        ...
# Uruguay   San Jose                  San Jose      NaN      NaN  Red Blend
#           Uruguay                    Uruguay      NaN      NaN     Tannat
#
#                                           winery
# country   province
# Albania   Mirditë                         Arbëri
# Argentina Mendoza Province  Bodega Catena Zapata
# ...                                          ...
# Uruguay   San Jose                Castillo Viejo
#           Uruguay                          Bouza
#
# [455 rows x 11 columns]

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#               len   min    max
# country
# Albania       2.0  20.0   20.0
# Argentina  5631.0   4.0  250.0
# ...           ...   ...    ...
# Ukraine       5.0  13.0   13.0
# Uruguay      92.0   7.0   60.0
#
# [48 rows x 3 columns]

# %% [markdown]
# ## Multi-indexs

# %%
country_province_reviews = reviews.groupby(['country', 'province']).description.agg([len])
country_province_reviews
# Out:
#                              len
# country   province
# Albania   Mirditë              2
# Argentina Mendoza Province  4742
# ...                          ...
# Uruguay   San Jose            15
#           Uruguay             18
#
# [455 rows x 1 columns]

# %%
type(country_province_reviews.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
country_province_reviews.reset_index()
# Out:
#        country          province   len
# 0      Albania           Mirditë     2
# 1    Argentina  Mendoza Province  4742
# ..         ...               ...   ...
# 453    Uruguay          San Jose    15
# 454    Uruguay           Uruguay    18
#
# [455 rows x 3 columns]

# %% [markdown]
# ## Sorting

# %%
country_province_reviews = country_province_reviews.reset_index()

# %%
country_province_reviews.sort_values(by = 'len', ascending=False)
# Out:
#          country                                province    len
# 422           US                              California  44508
# 442           US                              Washington   9750
# ..           ...                                     ...    ...
# 413  Switzerland  Vino da Tavola della Svizzera Italiana      1
# 175       Greece                          Krania Olympus      1
#
# [455 rows x 3 columns]

# %%
country_province_reviews.sort_values(by = ['country', 'len'])
# Out:
#        country   province  len
# 0      Albania    Mirditë    2
# 2    Argentina      Other  889
# ..         ...        ...  ...
# 447    Uruguay  Canelones   19
# 450    Uruguay    Juanico   19
#
# [455 rows x 3 columns]

# %%
country_province_reviews.sort_index()
# Out:
#        country          province   len
# 0      Albania           Mirditë     2
# 1    Argentina  Mendoza Province  4742
# ..         ...               ...   ...
# 453    Uruguay          San Jose    15
# 454    Uruguay           Uruguay    18
#
# [455 rows x 3 columns]

# %% [markdown]
# # 4. Data Types and Missing Values

# %%
reviews = pd.read_csv('./winemag-data_first150k.csv', index_col=0)

# %% [markdown]
# ## Dtypes

# %%
reviews.points.dtype
# Out:
# dtype('int64')

# %%
# 's'
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 10, dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         96.0
# 1         96.0
#           ...
# 150928    90.0
# 150929    90.0
# Name: points, Length: 150930, dtype: float64

# %%
# index also has its `dtype`
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Missing data

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
reviews.region_2.fillna('Unknown')
# Out:
# 0            Napa
# 1         Unknown
#            ...
# 150928    Unknown
# 150929    Unknown
# Name: region_2, Length: 150930, dtype: object

# %%
reviews.region_2.unique()
# Out:
# array(['Napa', nan, 'Sonoma', 'Willamette Valley', 'Central Coast',
#        'Columbia Valley', 'Finger Lakes', 'California Other',
#        'Mendocino/Lake Counties', 'South Coast', 'Central Valley',
#        'New York Other', 'Sierra Foothills', 'Southern Oregon',
#        'Oregon Other', 'Napa-Sonoma', 'North Coast', 'Washington Other',
#        'Long Island'], dtype=object)

# %% [markdown]
# # 6. Renaming and Combining

# %% [markdown]
# ## Renaming

# %%
reviews = pd.read_csv('./winemag-data_first150k.csv')

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...            ...     ...                                                ...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  score  price  \
# 0                          Martha's Vineyard     96  235.0
# 1       Carodorum Selección Especial Reserva     96  110.0
# ...                                      ...    ...    ...
# 150928                       Grand Brut Rosé     90   52.0
# 150929                                   NaN     90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# ...                         ...
# 150928                   Gosset
# 150929            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
reviews.rename(index = {0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Unnamed: 0 country  \
# firstEntry            0      US
# secondEntry           1   Spain
# ...                 ...     ...
# 150928           150928  France
# 150929           150929   Italy
#
#                                                    description  \
# firstEntry   This tremendous 100% varietal wine hails from ...
# secondEntry  Ripe aromas of fig, blackberry and cassis are ...
# ...                                                        ...
# 150928       A perfect salmon shade, with scents of peaches...
# 150929       More Pinot Grigios should taste like this. A r...
#
#                                       designation  points  price  \
# firstEntry                      Martha's Vineyard      96  235.0
# secondEntry  Carodorum Selección Especial Reserva      96  110.0
# ...                                           ...     ...    ...
# 150928                            Grand Brut Rosé      90   52.0
# 150929                                        NaN      90   15.0
#
#                        province     region_1 region_2             variety  \
# firstEntry           California  Napa Valley     Napa  Cabernet Sauvignon
# secondEntry      Northern Spain         Toro      NaN       Tinta de Toro
# ...                         ...          ...      ...                 ...
# 150928                Champagne    Champagne      NaN     Champagne Blend
# 150929       Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                               winery
# firstEntry                     Heitz
# secondEntry  Bodega Carmen Rodríguez
# ...                              ...
# 150928                        Gosset
# 150929                 Alois Lageder
#
# [150930 rows x 11 columns]

# %%
reviews.rename_axis('wines', axis='rows').rename_axis('fields', axis='columns')
# Out:
# fields  Unnamed: 0 country                                        description  \
# wines
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...            ...     ...                                                ...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# fields                           designation  points  price  \
# wines
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
# fields            province     region_1 region_2             variety  \
# wines
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
# fields                   winery
# wines
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# ...                         ...
# 150928                   Gosset
# 150929            Alois Lageder
#
# [150930 rows x 11 columns]

# %% [markdown]
# ## Combining

# %%
pd.concat([reviews, reviews])
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...            ...     ...                                                ...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# 1           Northern Spain         Toro      NaN       Tinta de Toro
# ...                    ...          ...      ...                 ...
# 150928           Champagne    Champagne      NaN     Champagne Blend
# 150929  Northeastern Italy   Alto Adige      NaN        Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# ...                         ...
# 150928                   Gosset
# 150929            Alois Lageder
#
# [301860 rows x 11 columns]

# %%
left = reviews.iloc[0:100, :].set_index('points')
right = reviews.iloc[1000:1100, :].set_index('points')

# %%
left.join(right, lsuffix = '_1', rsuffix = '_2')
# Out:
#         Unnamed: 0_1 country_1  \
# points
# 86                90        US
# 86                91  Portugal
# ...              ...       ...
# 96                 2        US
# 96                 3        US
#
#                                             description_1  \
# points
# 86      Bright, light oak shadings dress up this mediu...
# 86      The local Baga grape, better known for produci...
# ...                                                   ...
# 96      Mac Watson honors the memory of a wine once ma...
# 96      This spent 20 months in 30% new French oak, an...
#
#                          designation_1  price_1       province_1  \
# points
# 86                                 NaN     10.0       California
# 86      Marquês de Marialva Rosé Bruto     12.0  Beira Atlantico
# ...                                ...      ...              ...
# 96       Special Selected Late Harvest     90.0       California
# 96                             Reserve     65.0           Oregon
#
#                region_1_1         region_2_1           variety_1  \
# points
# 86             California   California Other  Cabernet Sauvignon
# 86                    NaN                NaN                Baga
# ...                   ...                ...                 ...
# 96         Knights Valley             Sonoma     Sauvignon Blanc
# 96      Willamette Valley  Willamette Valley          Pinot Noir
#
#                    winery_1  Unnamed: 0_2 country_2 description_2  \
# points
# 86           Belle Ambiance           NaN       NaN           NaN
# 86      Adega de Cantanhede           NaN       NaN           NaN
# ...                     ...           ...       ...           ...
# 96                 Macauley           NaN       NaN           NaN
# 96                    Ponzi           NaN       NaN           NaN
#
#        designation_2  price_2 province_2 region_1_2 region_2_2 variety_2  \
# points
# 86               NaN      NaN        NaN        NaN        NaN       NaN
# 86               NaN      NaN        NaN        NaN        NaN       NaN
# ...              ...      ...        ...        ...        ...       ...
# 96               NaN      NaN        NaN        NaN        NaN       NaN
# 96               NaN      NaN        NaN        NaN        NaN       NaN
#
#        winery_2
# points
# 86          NaN
# 86          NaN
# ...         ...
# 96          NaN
# 96          NaN
#
# [970 rows x 20 columns]
